# %%
# Getting the data ready 
import pandas as pd
taxi = pd.read_csv("Uber_Trips_NYC_2016.csv")
taxi
# Out:
#      Base License Number  Wave Number         Base Name  \
# 0                 B02865            4       VIER-NY,LLC
# 1                 B02883            4  SECHZEHN-NY, LLC
# 2                 B02765            1          GRUN LLC
# 3                 B02875            4     SECHS-NY, LLC
# 4                 B02865            4       VIER-NY,LLC
# ...                  ...          ...               ...
# 1469              B02878            4        ELF-NY,LLC
# 1470              B02866            4       ZWEI-NY,LLC
# 1471              B02883            4  SECHZEHN-NY, LLC
# 1472              B02764            1     DANACH-NY,LLC
# 1473              B02871            4       ACHT-NY,LLC
#
#                         DBA  Years  Week Number Pickup Start Date  \
# 0          UBER-VIER-NY LLC   2016           40         9/25/2016
# 1     UBER-SECHZEHN-NY, LLC   2016           39         9/18/2016
# 2             UBER-GRUN LLC   2016            5         1/24/2016
# ...

# %%
taxi.dtypes
# Out:
# Base License Number          object
# Wave Number                   int64
# Base Name                    object
# DBA                          object
# Years                         int64
# Week Number                   int64
# Pickup Start Date            object
# Pickup End Date              object
# Total Dispatched Trips        int64
# Unique Dispatched Vehicle     int64
# dtype: object
